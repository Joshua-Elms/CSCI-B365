# %% [markdown]
# Necessary imports are vast, but generally either: standard DS library or particular ML algorithm

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import *
from sklearn.model_selection import *
from sklearn.metrics import *

from sklearn.linear_model import LinearRegression
from lightgbm import LGBMRegressor
from xgboost.sklearn import XGBRegressor
from catboost import CatBoostRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import BayesianRidge
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
# %matplotlib qt
rng = np.random.default_rng(100)

SMALL_SIZE = 20
MEDIUM_SIZE = 24
BIGGER_SIZE = 32
CHONK_SIZE = 38
font = {'family' : 'DIN Condensed',
        'weight' : 'bold',
        'size'   : SMALL_SIZE}
plt.rc('font', **font)
plt.rc('axes', titlesize=BIGGER_SIZE, labelsize=MEDIUM_SIZE, facecolor="xkcd:white")
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=CHONK_SIZE, facecolor="xkcd:white", edgecolor="xkcd:black") #  powder blue

drop_lst = ["MU CAPE", "MU CIN", "MU LCL", "MU LFC", "MU EL", "MU LI", "MU hght0c", "MU cap", "MU b3km", "MU brn", "SB CAPE", "SB CIN", "SB LCL", "SB LFC", "SB EL", "SB LI", "SB hght0c",
"SB cap", "SB b3km", "SB brn", "sb_tlcl", "mu_tlcl"]

col_names = ['CAPE', 'CIN', 'LCL', 'LFC', 'EL', 'LI', 'HGHT0C',
            'CAP', 'B3KM', 'BRN', 'SHEAR 0-1 KM', 'SHEAR 0-6 KM',
            'EFF INFLOW', 'EBWD', 'SRH 0-1 KM', 'SRH 0-3 KM', 'EFF SRH', 'SCP',
            'STP-FIXED', 'STP-MIXED', 'SHIP', 'PWAT', 'DCAPE', 'MLMR', 'LRAT',
            'TEI', 'TLCL', 'T500', 'SWEAT', 'K-INDEX', 'CRAV', 'HAIL SIZE IN']

# %% [markdown]
# Limited preprocessing here, just reading in data, scaling it, and going with train:test split of 3:1.

# %%
path = "/Users/joshuaelms/Desktop/github_repos/CSCI-B365/Meteorology_Modeling_Project/data/pretty_data.csv"
df = pd.read_csv(path)

df_X = df.drop(labels = "Hailstone Size", axis = 1)
df_y = df["Hailstone Size"]

X = df_X.values
y = df_y.values

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.25, random_state = 1879)

# %% [markdown]
# Perform 5-fold cross validation for 10 different algorithms, sort list by which algorithm performs best.
#
# Note: should have kept time variable in equations here, as cross-validation can be aided by time (not IID otherwise)

# %%
algorithms = [LinearRegression(), LGBMRegressor(), XGBRegressor(), CatBoostRegressor(), SGDRegressor(), KernelRidge(), ElasticNet(), BayesianRidge(), GradientBoostingRegressor(), SVR()]
names = ["LinearRegression", "LGBMRegressor", "XGBRegressor", "CatBoostRegressor", "SGDRegressor", "KernelRidge", "ElasticNet", "BayesianRidge", "GradientBoostingRegressor", "SVR"]

performance_dict = {}

for i, algorithm in enumerate(algorithms):
    kwargs = {"estimator": algorithm, "X": X_train, "y": y_train, "cv": 5, "return_estimator": True}
    results_dict = cross_validate(**kwargs)
    # test_scores = 
    performance_dict[names[i]] = results_dict

performance_dict
# Out:
# Learning rate set to 0.064331
# 0:	learn: 0.5222489	total: 53.1ms	remaining: 53s
# 1:	learn: 0.5206851	total: 68.1ms	remaining: 34s
# 2:	learn: 0.5192904	total: 79.2ms	remaining: 26.3s
# 3:	learn: 0.5178247	total: 94.9ms	remaining: 23.6s
# 4:	learn: 0.5166476	total: 106ms	remaining: 21.2s
# 54:	learn: 0.4962153	total: 1.02s	remaining: 17.6s
# 55:	learn: 0.4960240	total: 1.03s	remaining: 17.5s
# 56:	learn: 0.4958985	total: 1.05s	remaining: 17.4s
# 57:	learn: 0.4957067	total: 1.1s	remaining: 17.8s
# 58:	learn: 0.4955342	total: 1.13s	remaining: 18.1s
# 59:	learn: 0.4952656	total: 1.15s	remaining: 18s
# 60:	learn: 0.4950683	total: 1.18s	remaining: 18.2s
# 61:	learn: 0.4948993	total: 1.2s	remaining: 18.1s
# 62:	learn: 0.4946053	total: 1.21s	remaining: 18s
# 63:	learn: 0.4944767	total: 1.22s	remaining: 17.9s
# 64:	learn: 0.4943843	total: 1.23s	remaining: 17.7s
# 65:	learn: 0.4941969	total: 1.24s	remaining: 17.6s
# 66:	learn: 0.4938829	total: 1.28s	remaining: 17.8s
# 67:	learn: 0.4936927	total: 1.32s	remaining: 18.1s
# 68:	learn: 0.4935164	total: 1.33s	remaining: 18s
# 69:	learn: 0.4933289	total: 1.35s	remaining: 17.9s
# 70:	learn: 0.4931033	total: 1.36s	remaining: 17.9s
# 71:	learn: 0.4928433	total: 1.38s	remaining: 17.7s
# 72:	learn: 0.4927259	total: 1.39s	remaining: 17.6s
# 73:	learn: 0.4925256	total: 1.4s	remaining: 17.5s
# 74:	learn: 0.4923992	total: 1.52s	remaining: 18.7s
# 75:	learn: 0.4922569	total: 1.56s	remaining: 18.9s
# 76:	learn: 0.4919605	total: 1.57s	remaining: 18.8s
# 77:	learn: 0.4917729	total: 1.58s	remaining: 18.7s
# 78:	learn: 0.4915978	total: 1.6s	remaining: 18.6s
# 79:	learn: 0.4913697	total: 1.61s	remaining: 18.5s
# 80:	learn: 0.4911883	total: 1.62s	remaining: 18.4s
# 81:	learn: 0.4910114	total: 1.63s	remaining: 18.3s
# 82:	learn: 0.4907292	total: 1.65s	remaining: 18.2s
# 83:	learn: 0.4905529	total: 1.66s	remaining: 18.2s
# 84:	learn: 0.4903644	total: 1.68s	remaining: 18.1s
# 85:	learn: 0.4902435	total: 1.69s	remaining: 17.9s
# 86:	learn: 0.4901020	total: 1.7s	remaining: 17.9s
# 87:	learn: 0.4899165	total: 1.71s	remaining: 17.8s
# 88:	learn: 0.4897822	total: 1.77s	remaining: 18.2s
# 89:	learn: 0.4896361	total: 1.8s	remaining: 18.2s
# 90:	learn: 0.4894384	total: 1.81s	remaining: 18.1s
# 91:	learn: 0.4893073	total: 1.83s	remaining: 18s
# 92:	learn: 0.4890972	total: 1.84s	remaining: 17.9s
# 93:	learn: 0.4889507	total: 1.85s	remaining: 17.8s
# 94:	learn: 0.4887432	total: 1.86s	remaining: 17.7s
# 95:	learn: 0.4886310	total: 1.87s	remaining: 17.7s
# 96:	learn: 0.4885108	total: 1.89s	remaining: 17.6s
# 97:	learn: 0.4883714	total: 1.9s	remaining: 17.5s
# 98:	learn: 0.4882244	total: 1.91s	remaining: 17.4s
# 99:	learn: 0.4881032	total: 1.93s	remaining: 17.3s
# 100:	learn: 0.4878923	total: 1.96s	remaining: 17.4s
# 101:	learn: 0.4878166	total: 1.98s	remaining: 17.5s
# 340:	learn: 0.4508299	total: 5.55s	remaining: 10.7s
# 341:	learn: 0.4507117	total: 5.57s	remaining: 10.7s
# 342:	learn: 0.4505917	total: 5.58s	remaining: 10.7s
# 343:	learn: 0.4504601	total: 5.59s	remaining: 10.7s
# 344:	learn: 0.4503440	total: 5.6s	remaining: 10.6s
# 345:	learn: 0.4502224	total: 5.61s	remaining: 10.6s
# 346:	learn: 0.4500528	total: 5.62s	remaining: 10.6s
# 347:	learn: 0.4499275	total: 5.66s	remaining: 10.6s
# 348:	learn: 0.4498178	total: 5.68s	remaining: 10.6s
# 349:	learn: 0.4496425	total: 5.69s	remaining: 10.6s
# 350:	learn: 0.4494903	total: 5.7s	remaining: 10.5s
# 351:	learn: 0.4494222	total: 5.72s	remaining: 10.5s
# 352:	learn: 0.4492844	total: 5.73s	remaining: 10.5s
# 353:	learn: 0.4492106	total: 5.74s	remaining: 10.5s
# 354:	learn: 0.4490772	total: 5.75s	remaining: 10.5s
# 355:	learn: 0.4489343	total: 5.77s	remaining: 10.4s
# 356:	learn: 0.4488266	total: 5.78s	remaining: 10.4s
# 357:	learn: 0.4486410	total: 5.79s	remaining: 10.4s
# 358:	learn: 0.4484518	total: 5.8s	remaining: 10.4s
# 359:	learn: 0.4482613	total: 5.81s	remaining: 10.3s
# 360:	learn: 0.4481866	total: 5.82s	remaining: 10.3s
# 361:	learn: 0.4480936	total: 5.84s	remaining: 10.3s
# 362:	learn: 0.4479532	total: 5.87s	remaining: 10.3s
# 363:	learn: 0.4478079	total: 5.89s	remaining: 10.3s
# 364:	learn: 0.4476142	total: 5.9s	remaining: 10.3s
# 365:	learn: 0.4474272	total: 5.91s	remaining: 10.2s
# 366:	learn: 0.4472013	total: 5.92s	remaining: 10.2s
# 367:	learn: 0.4471274	total: 5.94s	remaining: 10.2s
# 368:	learn: 0.4470521	total: 5.95s	remaining: 10.2s
# 369:	learn: 0.4468772	total: 5.96s	remaining: 10.2s
# 370:	learn: 0.4467264	total: 5.97s	remaining: 10.1s
# 371:	learn: 0.4465850	total: 5.98s	remaining: 10.1s
# 372:	learn: 0.4463623	total: 6s	remaining: 10.1s
# 373:	learn: 0.4461609	total: 6s	remaining: 10.1s
# 374:	learn: 0.4460368	total: 6.02s	remaining: 10s
# 375:	learn: 0.4459088	total: 6.03s	remaining: 10s
# 376:	learn: 0.4458014	total: 6.04s	remaining: 9.99s
# 377:	learn: 0.4457054	total: 6.07s	remaining: 9.99s
# 378:	learn: 0.4456005	total: 6.08s	remaining: 9.97s
# 379:	learn: 0.4454342	total: 6.1s	remaining: 9.95s
# 380:	learn: 0.4453531	total: 6.11s	remaining: 9.93s
# 381:	learn: 0.4451390	total: 6.12s	remaining: 9.9s
# 382:	learn: 0.4449434	total: 6.13s	remaining: 9.88s
# 383:	learn: 0.4447333	total: 6.15s	remaining: 9.86s
# 384:	learn: 0.4445771	total: 6.16s	remaining: 9.84s
# 385:	learn: 0.4444780	total: 6.17s	remaining: 9.82s
# 386:	learn: 0.4443502	total: 6.18s	remaining: 9.79s
# 387:	learn: 0.4442359	total: 6.19s	remaining: 9.77s
# 625:	learn: 0.4160331	total: 9.74s	remaining: 5.82s
# 626:	learn: 0.4158883	total: 9.75s	remaining: 5.8s
# 627:	learn: 0.4157654	total: 9.76s	remaining: 5.78s
# 628:	learn: 0.4156731	total: 9.78s	remaining: 5.77s
# 629:	learn: 0.4154772	total: 9.79s	remaining: 5.75s
# 630:	learn: 0.4154174	total: 9.8s	remaining: 5.73s
# 631:	learn: 0.4153280	total: 9.81s	remaining: 5.71s
# 632:	learn: 0.4152294	total: 9.82s	remaining: 5.7s
# 633:	learn: 0.4151427	total: 9.84s	remaining: 5.68s
# 634:	learn: 0.4150408	total: 9.88s	remaining: 5.68s
# 635:	learn: 0.4149222	total: 9.89s	remaining: 5.66s
# 636:	learn: 0.4148349	total: 9.9s	remaining: 5.64s
# 637:	learn: 0.4147134	total: 9.91s	remaining: 5.63s
# 638:	learn: 0.4146375	total: 9.93s	remaining: 5.61s
# 639:	learn: 0.4145008	total: 9.94s	remaining: 5.59s
# 640:	learn: 0.4143880	total: 9.95s	remaining: 5.57s
# 641:	learn: 0.4142586	total: 9.96s	remaining: 5.55s
# 642:	learn: 0.4141619	total: 9.97s	remaining: 5.54s
# 643:	learn: 0.4140463	total: 9.99s	remaining: 5.52s
# 644:	learn: 0.4139523	total: 10s	remaining: 5.5s
# 645:	learn: 0.4138193	total: 10s	remaining: 5.48s
# 646:	learn: 0.4137590	total: 10s	remaining: 5.46s
# 647:	learn: 0.4136597	total: 10s	remaining: 5.45s
# 648:	learn: 0.4135815	total: 10s	remaining: 5.43s
# 649:	learn: 0.4134892	total: 10.1s	remaining: 5.41s
# 650:	learn: 0.4134326	total: 10.1s	remaining: 5.41s
# 651:	learn: 0.4133596	total: 10.1s	remaining: 5.39s
# 652:	learn: 0.4132317	total: 10.1s	remaining: 5.38s
# 653:	learn: 0.4131543	total: 10.1s	remaining: 5.37s
# 654:	learn: 0.4130498	total: 10.2s	remaining: 5.35s
# 655:	learn: 0.4129480	total: 10.2s	remaining: 5.33s
# 656:	learn: 0.4128256	total: 10.2s	remaining: 5.32s
# 657:	learn: 0.4126442	total: 10.2s	remaining: 5.3s
# 658:	learn: 0.4125064	total: 10.2s	remaining: 5.28s
# 659:	learn: 0.4123982	total: 10.2s	remaining: 5.26s
# 660:	learn: 0.4123070	total: 10.2s	remaining: 5.25s
# 661:	learn: 0.4122395	total: 10.2s	remaining: 5.23s
# 662:	learn: 0.4121444	total: 10.3s	remaining: 5.21s
# 663:	learn: 0.4120333	total: 10.3s	remaining: 5.21s
# 664:	learn: 0.4119371	total: 10.3s	remaining: 5.19s
# 665:	learn: 0.4118246	total: 10.3s	remaining: 5.18s
# 666:	learn: 0.4117231	total: 10.3s	remaining: 5.16s
# 667:	learn: 0.4116008	total: 10.3s	remaining: 5.14s
# 668:	learn: 0.4114511	total: 10.4s	remaining: 5.12s
# 669:	learn: 0.4113632	total: 10.4s	remaining: 5.11s
# 670:	learn: 0.4112172	total: 10.4s	remaining: 5.09s
# 671:	learn: 0.4111130	total: 10.4s	remaining: 5.07s
# 672:	learn: 0.4110066	total: 10.4s	remaining: 5.06s
# 673:	learn: 0.4109213	total: 10.4s	remaining: 5.04s
# 674:	learn: 0.4108427	total: 10.4s	remaining: 5.02s
# 675:	learn: 0.4107697	total: 10.4s	remaining: 5s
# 676:	learn: 0.4106933	total: 10.5s	remaining: 4.99s
# 677:	learn: 0.4105843	total: 10.5s	remaining: 4.98s
# 678:	learn: 0.4105081	total: 10.5s	remaining: 4.97s
# 679:	learn: 0.4104440	total: 10.5s	remaining: 4.95s
# 680:	learn: 0.4103743	total: 10.5s	remaining: 4.93s
# 681:	learn: 0.4102844	total: 10.5s	remaining: 4.91s
# 682:	learn: 0.4102217	total: 10.5s	remaining: 4.89s
# 683:	learn: 0.4101083	total: 10.6s	remaining: 4.88s
# 684:	learn: 0.4100105	total: 10.6s	remaining: 4.86s
# 685:	learn: 0.4099555	total: 10.6s	remaining: 4.84s
# 686:	learn: 0.4098967	total: 10.6s	remaining: 4.83s
# 687:	learn: 0.4097819	total: 10.6s	remaining: 4.81s
# 688:	learn: 0.4095736	total: 10.6s	remaining: 4.79s
# 689:	learn: 0.4094241	total: 10.6s	remaining: 4.77s
# 690:	learn: 0.4092784	total: 10.6s	remaining: 4.76s
# 691:	learn: 0.4092208	total: 10.7s	remaining: 4.74s
# 692:	learn: 0.4090721	total: 10.7s	remaining: 4.73s
# 693:	learn: 0.4089385	total: 10.7s	remaining: 4.72s
# 694:	learn: 0.4088196	total: 10.7s	remaining: 4.7s
# 695:	learn: 0.4087212	total: 10.7s	remaining: 4.68s
# 696:	learn: 0.4085945	total: 10.7s	remaining: 4.67s
# 697:	learn: 0.4085046	total: 10.7s	remaining: 4.65s
# 698:	learn: 0.4083941	total: 10.8s	remaining: 4.63s
# 699:	learn: 0.4083233	total: 10.8s	remaining: 4.62s
# 700:	learn: 0.4081400	total: 10.8s	remaining: 4.6s
# 701:	learn: 0.4079849	total: 10.8s	remaining: 4.58s
# 702:	learn: 0.4078302	total: 10.8s	remaining: 4.56s
# 703:	learn: 0.4077672	total: 10.8s	remaining: 4.55s
# 704:	learn: 0.4076559	total: 10.8s	remaining: 4.53s
# 705:	learn: 0.4075515	total: 10.8s	remaining: 4.51s
# 706:	learn: 0.4074593	total: 10.9s	remaining: 4.5s
# 707:	learn: 0.4073513	total: 10.9s	remaining: 4.49s
# 708:	learn: 0.4072791	total: 10.9s	remaining: 4.48s
# 709:	learn: 0.4071668	total: 10.9s	remaining: 4.46s
# 710:	learn: 0.4070335	total: 10.9s	remaining: 4.44s
# 711:	learn: 0.4069038	total: 10.9s	remaining: 4.42s
# 712:	learn: 0.4068035	total: 11s	remaining: 4.41s
# 713:	learn: 0.4067442	total: 11s	remaining: 4.39s
# 714:	learn: 0.4065900	total: 11s	remaining: 4.38s
# 715:	learn: 0.4065195	total: 11s	remaining: 4.36s
# 716:	learn: 0.4063925	total: 11s	remaining: 4.34s
# 717:	learn: 0.4062685	total: 11s	remaining: 4.32s
# 718:	learn: 0.4061809	total: 11s	remaining: 4.31s
# 719:	learn: 0.4060985	total: 11s	remaining: 4.29s
# 768:	learn: 0.4015337	total: 11.7s	remaining: 3.52s
# 769:	learn: 0.4014740	total: 11.7s	remaining: 3.5s
# 770:	learn: 0.4013380	total: 11.7s	remaining: 3.49s
# 771:	learn: 0.4012314	total: 11.8s	remaining: 3.47s
# 772:	learn: 0.4010883	total: 11.8s	remaining: 3.46s
# 773:	learn: 0.4009573	total: 11.8s	remaining: 3.44s
# 774:	learn: 0.4008020	total: 11.8s	remaining: 3.42s
# 775:	learn: 0.4007164	total: 11.8s	remaining: 3.41s
# 776:	learn: 0.4006612	total: 11.8s	remaining: 3.39s
# 777:	learn: 0.4005912	total: 11.8s	remaining: 3.38s
# 778:	learn: 0.4004338	total: 11.8s	remaining: 3.36s
# 779:	learn: 0.4003178	total: 11.9s	remaining: 3.34s
# 780:	learn: 0.4002545	total: 11.9s	remaining: 3.33s
# 781:	learn: 0.4001765	total: 11.9s	remaining: 3.32s
# 782:	learn: 0.4000800	total: 11.9s	remaining: 3.3s
# 783:	learn: 0.3999490	total: 11.9s	remaining: 3.29s
# 784:	learn: 0.3998760	total: 11.9s	remaining: 3.27s
# 785:	learn: 0.3997923	total: 11.9s	remaining: 3.25s
# 786:	learn: 0.3997288	total: 12s	remaining: 3.24s
# 787:	learn: 0.3996052	total: 12s	remaining: 3.22s
# 788:	learn: 0.3995427	total: 12s	remaining: 3.21s
# 789:	learn: 0.3993962	total: 12s	remaining: 3.19s
# 790:	learn: 0.3992845	total: 12s	remaining: 3.17s
# 791:	learn: 0.3992062	total: 12s	remaining: 3.16s
# 792:	learn: 0.3991157	total: 12s	remaining: 3.14s
# 793:	learn: 0.3990633	total: 12s	remaining: 3.13s
# 794:	learn: 0.3989933	total: 12.1s	remaining: 3.12s
# 795:	learn: 0.3989025	total: 12.1s	remaining: 3.1s
# 796:	learn: 0.3988376	total: 12.1s	remaining: 3.08s
# 797:	learn: 0.3987549	total: 12.1s	remaining: 3.07s
# 798:	learn: 0.3986587	total: 12.1s	remaining: 3.05s
# 799:	learn: 0.3985578	total: 12.1s	remaining: 3.04s
# 800:	learn: 0.3984979	total: 12.2s	remaining: 3.02s
# 801:	learn: 0.3984170	total: 12.2s	remaining: 3s
# 802:	learn: 0.3982753	total: 12.2s	remaining: 2.99s
# 803:	learn: 0.3982121	total: 12.2s	remaining: 2.97s
# 804:	learn: 0.3981117	total: 12.2s	remaining: 2.96s
# 805:	learn: 0.3980518	total: 12.2s	remaining: 2.94s
# 806:	learn: 0.3979289	total: 12.2s	remaining: 2.92s
# 807:	learn: 0.3978163	total: 12.2s	remaining: 2.91s
# 808:	learn: 0.3976686	total: 12.2s	remaining: 2.89s
# 809:	learn: 0.3975658	total: 12.3s	remaining: 2.88s
# 810:	learn: 0.3974739	total: 12.3s	remaining: 2.87s
# 811:	learn: 0.3974553	total: 12.3s	remaining: 2.85s
# 812:	learn: 0.3973692	total: 12.3s	remaining: 2.83s
# 813:	learn: 0.3972555	total: 12.3s	remaining: 2.82s
# 814:	learn: 0.3972029	total: 12.4s	remaining: 2.8s
# 815:	learn: 0.3970565	total: 12.4s	remaining: 2.79s
# 816:	learn: 0.3969386	total: 12.4s	remaining: 2.77s
# 817:	learn: 0.3968892	total: 12.4s	remaining: 2.76s
# 818:	learn: 0.3968079	total: 12.4s	remaining: 2.74s
# 819:	learn: 0.3967428	total: 12.4s	remaining: 2.73s
# 820:	learn: 0.3966522	total: 12.4s	remaining: 2.71s
# 821:	learn: 0.3965888	total: 12.4s	remaining: 2.69s
# 822:	learn: 0.3964924	total: 12.5s	remaining: 2.68s
# 823:	learn: 0.3963937	total: 12.5s	remaining: 2.67s
# 824:	learn: 0.3963025	total: 12.5s	remaining: 2.65s
# 825:	learn: 0.3962124	total: 12.5s	remaining: 2.64s
# 826:	learn: 0.3961095	total: 12.5s	remaining: 2.62s
# 827:	learn: 0.3960381	total: 12.5s	remaining: 2.61s
# 828:	learn: 0.3959653	total: 12.6s	remaining: 2.59s
# 829:	learn: 0.3958256	total: 12.6s	remaining: 2.58s
# 830:	learn: 0.3957200	total: 12.6s	remaining: 2.56s
# 831:	learn: 0.3955724	total: 12.6s	remaining: 2.54s
# 832:	learn: 0.3954679	total: 12.6s	remaining: 2.53s
# 833:	learn: 0.3953554	total: 12.6s	remaining: 2.51s
# 834:	learn: 0.3952859	total: 12.6s	remaining: 2.5s
# 835:	learn: 0.3951820	total: 12.6s	remaining: 2.48s
# 836:	learn: 0.3950650	total: 12.7s	remaining: 2.46s
# 837:	learn: 0.3949804	total: 12.7s	remaining: 2.45s
# 838:	learn: 0.3948400	total: 12.7s	remaining: 2.44s
# 839:	learn: 0.3947322	total: 12.7s	remaining: 2.42s
# 840:	learn: 0.3946317	total: 12.7s	remaining: 2.41s
# 841:	learn: 0.3945319	total: 12.7s	remaining: 2.39s
# 842:	learn: 0.3944500	total: 12.8s	remaining: 2.38s
# 843:	learn: 0.3943212	total: 12.8s	remaining: 2.36s
# 844:	learn: 0.3942395	total: 12.8s	remaining: 2.34s
# 845:	learn: 0.3941837	total: 12.8s	remaining: 2.33s
# 846:	learn: 0.3940769	total: 12.8s	remaining: 2.31s
# 847:	learn: 0.3940274	total: 12.8s	remaining: 2.3s
# 848:	learn: 0.3939259	total: 12.8s	remaining: 2.28s
# 849:	learn: 0.3938484	total: 12.8s	remaining: 2.27s
# 850:	learn: 0.3937529	total: 12.9s	remaining: 2.25s
# 851:	learn: 0.3936505	total: 12.9s	remaining: 2.23s
# 852:	learn: 0.3935587	total: 12.9s	remaining: 2.22s
# 853:	learn: 0.3934483	total: 12.9s	remaining: 2.21s
# 854:	learn: 0.3933758	total: 12.9s	remaining: 2.19s
# 855:	learn: 0.3932892	total: 12.9s	remaining: 2.18s
# 856:	learn: 0.3932208	total: 12.9s	remaining: 2.16s
# 857:	learn: 0.3931233	total: 13s	remaining: 2.14s
# 858:	learn: 0.3930076	total: 13s	remaining: 2.13s
# 859:	learn: 0.3929172	total: 13s	remaining: 2.11s
# 860:	learn: 0.3928106	total: 13s	remaining: 2.1s
# 861:	learn: 0.3927586	total: 13s	remaining: 2.08s
# 862:	learn: 0.3926508	total: 13s	remaining: 2.07s
# 863:	learn: 0.3925691	total: 13s	remaining: 2.05s
# 864:	learn: 0.3924217	total: 13s	remaining: 2.04s
# 865:	learn: 0.3923534	total: 13.1s	remaining: 2.02s
# 866:	learn: 0.3922218	total: 13.1s	remaining: 2s
# 867:	learn: 0.3921387	total: 13.1s	remaining: 1.99s
# 868:	learn: 0.3920546	total: 13.1s	remaining: 1.97s
# 869:	learn: 0.3919896	total: 13.1s	remaining: 1.96s
# 870:	learn: 0.3919379	total: 13.1s	remaining: 1.95s
# 871:	learn: 0.3918679	total: 13.2s	remaining: 1.93s
# 872:	learn: 0.3917890	total: 13.2s	remaining: 1.92s
# 873:	learn: 0.3916679	total: 13.2s	remaining: 1.9s
# 874:	learn: 0.3915967	total: 13.2s	remaining: 1.88s
# 875:	learn: 0.3915480	total: 13.2s	remaining: 1.87s
# 876:	learn: 0.3914768	total: 13.2s	remaining: 1.85s
# 877:	learn: 0.3913415	total: 13.2s	remaining: 1.84s
# 878:	learn: 0.3912190	total: 13.2s	remaining: 1.82s
# 879:	learn: 0.3911465	total: 13.2s	remaining: 1.81s
# 880:	learn: 0.3910609	total: 13.3s	remaining: 1.79s
# 881:	learn: 0.3909730	total: 13.3s	remaining: 1.78s
# 882:	learn: 0.3908621	total: 13.3s	remaining: 1.76s
# 883:	learn: 0.3907504	total: 13.3s	remaining: 1.75s
# 884:	learn: 0.3906440	total: 13.3s	remaining: 1.73s
# 885:	learn: 0.3905764	total: 13.4s	remaining: 1.72s
# 886:	learn: 0.3904422	total: 13.4s	remaining: 1.7s
# 887:	learn: 0.3903002	total: 13.4s	remaining: 1.69s
# 888:	learn: 0.3902096	total: 13.4s	remaining: 1.67s
# 889:	learn: 0.3901206	total: 13.4s	remaining: 1.66s
# 890:	learn: 0.3900790	total: 13.4s	remaining: 1.64s
# 891:	learn: 0.3900019	total: 13.5s	remaining: 1.63s
# 892:	learn: 0.3899322	total: 13.5s	remaining: 1.61s
# 893:	learn: 0.3898186	total: 13.5s	remaining: 1.6s
# 894:	learn: 0.3897543	total: 13.5s	remaining: 1.58s
# 895:	learn: 0.3896517	total: 13.5s	remaining: 1.57s
# 896:	learn: 0.3895885	total: 13.5s	remaining: 1.55s
# 897:	learn: 0.3894858	total: 13.6s	remaining: 1.54s
# 898:	learn: 0.3893909	total: 13.6s	remaining: 1.52s
# 899:	learn: 0.3892729	total: 13.6s	remaining: 1.51s
# 900:	learn: 0.3891873	total: 13.6s	remaining: 1.49s
# 901:	learn: 0.3891237	total: 13.6s	remaining: 1.48s
# 902:	learn: 0.3890505	total: 13.6s	remaining: 1.46s
# 903:	learn: 0.3889402	total: 13.6s	remaining: 1.45s
# 904:	learn: 0.3888507	total: 13.6s	remaining: 1.43s
# 905:	learn: 0.3887676	total: 13.6s	remaining: 1.42s
# 906:	learn: 0.3886742	total: 13.7s	remaining: 1.4s
# 907:	learn: 0.3886172	total: 13.7s	remaining: 1.38s
# 908:	learn: 0.3885618	total: 13.7s	remaining: 1.37s
# 909:	learn: 0.3884840	total: 13.7s	remaining: 1.35s
# 910:	learn: 0.3884208	total: 13.7s	remaining: 1.34s
# 911:	learn: 0.3883413	total: 13.7s	remaining: 1.32s
# 912:	learn: 0.3882447	total: 13.8s	remaining: 1.31s
# 913:	learn: 0.3881006	total: 13.8s	remaining: 1.29s
# 914:	learn: 0.3880056	total: 13.8s	remaining: 1.28s
# 915:	learn: 0.3879069	total: 13.8s	remaining: 1.26s
# 916:	learn: 0.3878348	total: 13.8s	remaining: 1.25s
# 917:	learn: 0.3877509	total: 13.8s	remaining: 1.23s
# 918:	learn: 0.3876924	total: 13.8s	remaining: 1.22s
# 919:	learn: 0.3876111	total: 13.8s	remaining: 1.2s
# 920:	learn: 0.3875152	total: 13.8s	remaining: 1.19s
# 921:	learn: 0.3872813	total: 13.9s	remaining: 1.17s
# 922:	learn: 0.3871433	total: 13.9s	remaining: 1.16s
# 923:	learn: 0.3870351	total: 13.9s	remaining: 1.14s
# 924:	learn: 0.3869254	total: 13.9s	remaining: 1.13s
# 925:	learn: 0.3868372	total: 13.9s	remaining: 1.11s
# 926:	learn: 0.3867562	total: 13.9s	remaining: 1.1s
# 927:	learn: 0.3866702	total: 14s	remaining: 1.08s
# 928:	learn: 0.3865377	total: 14s	remaining: 1.07s
# ...
# 838:	learn: 0.3905681	total: 15.8s	remaining: 3.04s
# 839:	learn: 0.3904842	total: 15.8s	remaining: 3.02s
# 840:	learn: 0.3903802	total: 15.8s	remaining: 3s
# 841:	learn: 0.3902827	total: 15.9s	remaining: 2.98s
# 842:	learn: 0.3901509	total: 15.9s	remaining: 2.96s
# 843:	learn: 0.3900786	total: 15.9s	remaining: 2.94s
# 844:	learn: 0.3899930	total: 15.9s	remaining: 2.92s
# 845:	learn: 0.3898977	total: 15.9s	remaining: 2.9s
# 846:	learn: 0.3897676	total: 16s	remaining: 2.88s
# 847:	learn: 0.3896960	total: 16s	remaining: 2.86s
# 848:	learn: 0.3896136	total: 16s	remaining: 2.85s
# 849:	learn: 0.3895238	total: 16s	remaining: 2.83s
# 850:	learn: 0.3894382	total: 16s	remaining: 2.81s
# 851:	learn: 0.3893551	total: 16.1s	remaining: 2.79s
# 852:	learn: 0.3893025	total: 16.1s	remaining: 2.77s
# 853:	learn: 0.3892089	total: 16.1s	remaining: 2.76s
# 854:	learn: 0.3891001	total: 16.2s	remaining: 2.74s
# 855:	learn: 0.3889828	total: 16.2s	remaining: 2.72s
# 856:	learn: 0.3889227	total: 16.2s	remaining: 2.7s
# 857:	learn: 0.3888308	total: 16.2s	remaining: 2.68s
# 858:	learn: 0.3887432	total: 16.2s	remaining: 2.66s
# 859:	learn: 0.3886497	total: 16.2s	remaining: 2.64s
# 860:	learn: 0.3886022	total: 16.2s	remaining: 2.62s
# 861:	learn: 0.3885289	total: 16.3s	remaining: 2.6s
# 862:	learn: 0.3884938	total: 16.3s	remaining: 2.58s
# 863:	learn: 0.3883780	total: 16.5s	remaining: 2.6s
# 864:	learn: 0.3882293	total: 16.5s	remaining: 2.58s
# 865:	learn: 0.3881551	total: 16.6s	remaining: 2.56s
# 866:	learn: 0.3880657	total: 16.6s	remaining: 2.55s
# 867:	learn: 0.3879395	total: 16.7s	remaining: 2.54s
# 868:	learn: 0.3878935	total: 16.7s	remaining: 2.52s
# 869:	learn: 0.3877990	total: 16.7s	remaining: 2.5s
# 870:	learn: 0.3877020	total: 16.8s	remaining: 2.48s
# 871:	learn: 0.3876247	total: 16.8s	remaining: 2.46s
# 872:	learn: 0.3875441	total: 16.8s	remaining: 2.45s
# 873:	learn: 0.3874623	total: 16.8s	remaining: 2.43s
# 874:	learn: 0.3873666	total: 16.9s	remaining: 2.41s
# 875:	learn: 0.3872660	total: 16.9s	remaining: 2.39s
# 876:	learn: 0.3871876	total: 16.9s	remaining: 2.37s
# 877:	learn: 0.3871112	total: 16.9s	remaining: 2.35s
# 878:	learn: 0.3870063	total: 17s	remaining: 2.33s
# 879:	learn: 0.3869048	total: 17s	remaining: 2.31s
# 880:	learn: 0.3868307	total: 17s	remaining: 2.29s
# 881:	learn: 0.3867090	total: 17s	remaining: 2.27s
# 882:	learn: 0.3865846	total: 17s	remaining: 2.26s
# 883:	learn: 0.3864841	total: 17s	remaining: 2.24s
# 884:	learn: 0.3863734	total: 17.1s	remaining: 2.22s
# 885:	learn: 0.3862736	total: 17.1s	remaining: 2.2s
# 886:	learn: 0.3861699	total: 17.1s	remaining: 2.18s
# 887:	learn: 0.3860772	total: 17.1s	remaining: 2.16s
# 888:	learn: 0.3859983	total: 17.2s	remaining: 2.14s
# 889:	learn: 0.3859173	total: 17.2s	remaining: 2.12s
# 890:	learn: 0.3858042	total: 17.2s	remaining: 2.1s
# 891:	learn: 0.3856730	total: 17.2s	remaining: 2.08s
# 892:	learn: 0.3855397	total: 17.2s	remaining: 2.06s
# 893:	learn: 0.3854270	total: 17.3s	remaining: 2.04s
# 894:	learn: 0.3853185	total: 17.3s	remaining: 2.03s
# 895:	learn: 0.3852099	total: 17.3s	remaining: 2.01s
# 896:	learn: 0.3851658	total: 17.3s	remaining: 1.99s
# 897:	learn: 0.3850665	total: 17.4s	remaining: 1.97s
# 898:	learn: 0.3849901	total: 17.4s	remaining: 1.95s
# 899:	learn: 0.3848994	total: 17.4s	remaining: 1.93s
# 900:	learn: 0.3848274	total: 17.4s	remaining: 1.91s
# 901:	learn: 0.3847397	total: 17.4s	remaining: 1.89s
# 902:	learn: 0.3846674	total: 17.5s	remaining: 1.88s
# 903:	learn: 0.3845950	total: 17.5s	remaining: 1.85s
# 904:	learn: 0.3845457	total: 17.5s	remaining: 1.83s
# 905:	learn: 0.3844614	total: 17.5s	remaining: 1.82s
# 906:	learn: 0.3843244	total: 17.5s	remaining: 1.8s
# 907:	learn: 0.3842328	total: 17.6s	remaining: 1.78s
# 908:	learn: 0.3841585	total: 17.6s	remaining: 1.76s
# 909:	learn: 0.3840672	total: 17.6s	remaining: 1.74s
# 910:	learn: 0.3839796	total: 17.6s	remaining: 1.72s
# 911:	learn: 0.3839044	total: 17.6s	remaining: 1.7s
# 912:	learn: 0.3838629	total: 17.6s	remaining: 1.68s
# 913:	learn: 0.3838228	total: 17.6s	remaining: 1.66s
# 914:	learn: 0.3837210	total: 17.7s	remaining: 1.64s
# 915:	learn: 0.3836019	total: 17.7s	remaining: 1.62s
# 916:	learn: 0.3835260	total: 17.7s	remaining: 1.6s
# 917:	learn: 0.3834206	total: 17.7s	remaining: 1.58s
# 918:	learn: 0.3833681	total: 17.8s	remaining: 1.56s
# 919:	learn: 0.3832954	total: 17.8s	remaining: 1.54s
# 920:	learn: 0.3832230	total: 17.8s	remaining: 1.52s
# 921:	learn: 0.3831647	total: 17.8s	remaining: 1.5s
# 922:	learn: 0.3830622	total: 17.8s	remaining: 1.49s
# 923:	learn: 0.3829550	total: 17.8s	remaining: 1.47s
# 924:	learn: 0.3828749	total: 17.8s	remaining: 1.45s
# 925:	learn: 0.3828030	total: 17.8s	remaining: 1.43s
# 926:	learn: 0.3827261	total: 17.9s	remaining: 1.41s
# 927:	learn: 0.3826315	total: 17.9s	remaining: 1.39s
# 928:	learn: 0.3825351	total: 17.9s	remaining: 1.37s
# 929:	learn: 0.3824563	total: 17.9s	remaining: 1.35s
# 930:	learn: 0.3823888	total: 17.9s	remaining: 1.33s
# 931:	learn: 0.3822606	total: 18s	remaining: 1.31s
# 932:	learn: 0.3821870	total: 18s	remaining: 1.29s
# 933:	learn: 0.3820643	total: 18s	remaining: 1.27s
# 934:	learn: 0.3820111	total: 18s	remaining: 1.25s
# 935:	learn: 0.3819143	total: 18s	remaining: 1.23s
# 936:	learn: 0.3818601	total: 18.1s	remaining: 1.22s
# 937:	learn: 0.3817383	total: 18.1s	remaining: 1.2s
# 938:	learn: 0.3816326	total: 18.2s	remaining: 1.18s
# 939:	learn: 0.3815756	total: 18.2s	remaining: 1.16s
# 940:	learn: 0.3814803	total: 18.2s	remaining: 1.14s
# 941:	learn: 0.3813636	total: 18.2s	remaining: 1.12s
# 942:	learn: 0.3812752	total: 18.2s	remaining: 1.1s
# 943:	learn: 0.3811563	total: 18.2s	remaining: 1.08s
# 944:	learn: 0.3810862	total: 18.2s	remaining: 1.06s
# 945:	learn: 0.3809776	total: 18.3s	remaining: 1.04s
# 946:	learn: 0.3808893	total: 18.3s	remaining: 1.02s
# 947:	learn: 0.3808177	total: 18.3s	remaining: 1s
# 948:	learn: 0.3807507	total: 18.3s	remaining: 983ms
# 949:	learn: 0.3806814	total: 18.3s	remaining: 963ms
# 950:	learn: 0.3805570	total: 18.3s	remaining: 944ms
# 951:	learn: 0.3805258	total: 18.3s	remaining: 925ms
# 952:	learn: 0.3804817	total: 18.4s	remaining: 906ms
# 953:	learn: 0.3803891	total: 18.4s	remaining: 887ms
# 954:	learn: 0.3802551	total: 18.4s	remaining: 868ms
# 955:	learn: 0.3801725	total: 18.4s	remaining: 848ms
# 956:	learn: 0.3800610	total: 18.4s	remaining: 828ms
# 957:	learn: 0.3799229	total: 18.5s	remaining: 809ms
# 958:	learn: 0.3797713	total: 18.5s	remaining: 789ms
# 959:	learn: 0.3796190	total: 18.5s	remaining: 770ms
# 960:	learn: 0.3795573	total: 18.5s	remaining: 750ms
# 961:	learn: 0.3794855	total: 18.5s	remaining: 731ms
# 962:	learn: 0.3794249	total: 18.5s	remaining: 711ms
# 963:	learn: 0.3793371	total: 18.5s	remaining: 692ms
# 964:	learn: 0.3792448	total: 18.5s	remaining: 672ms
# 965:	learn: 0.3791502	total: 18.6s	remaining: 653ms
# 966:	learn: 0.3790840	total: 18.6s	remaining: 634ms
# 967:	learn: 0.3789987	total: 18.6s	remaining: 615ms
# 968:	learn: 0.3789051	total: 18.6s	remaining: 597ms
# 969:	learn: 0.3788510	total: 18.7s	remaining: 577ms
# 970:	learn: 0.3788345	total: 18.7s	remaining: 558ms
# 971:	learn: 0.3787668	total: 18.7s	remaining: 539ms
# 972:	learn: 0.3786188	total: 18.7s	remaining: 519ms
# 973:	learn: 0.3785806	total: 18.7s	remaining: 500ms
# 974:	learn: 0.3784919	total: 18.7s	remaining: 480ms
# 975:	learn: 0.3783903	total: 18.8s	remaining: 462ms
# 976:	learn: 0.3782900	total: 18.8s	remaining: 443ms
# 977:	learn: 0.3781949	total: 18.8s	remaining: 423ms
# 978:	learn: 0.3781220	total: 18.8s	remaining: 404ms
# 979:	learn: 0.3780294	total: 18.8s	remaining: 384ms
# 980:	learn: 0.3779628	total: 18.9s	remaining: 365ms
# 981:	learn: 0.3778972	total: 18.9s	remaining: 346ms
# 982:	learn: 0.3778054	total: 18.9s	remaining: 326ms
# 983:	learn: 0.3777040	total: 18.9s	remaining: 307ms
# 984:	learn: 0.3776329	total: 18.9s	remaining: 288ms
# 985:	learn: 0.3775691	total: 18.9s	remaining: 269ms
# 986:	learn: 0.3774462	total: 18.9s	remaining: 249ms
# 987:	learn: 0.3774028	total: 18.9s	remaining: 230ms
# 988:	learn: 0.3773153	total: 19.1s	remaining: 213ms
# 989:	learn: 0.3772028	total: 19.2s	remaining: 194ms
# 990:	learn: 0.3771308	total: 19.2s	remaining: 174ms
# 991:	learn: 0.3770450	total: 19.2s	remaining: 155ms
# 992:	learn: 0.3770069	total: 19.2s	remaining: 136ms
# 993:	learn: 0.3769042	total: 19.3s	remaining: 116ms
# 994:	learn: 0.3767964	total: 19.3s	remaining: 97.1ms
# 995:	learn: 0.3767498	total: 19.3s	remaining: 77.6ms
# 996:	learn: 0.3766877	total: 19.3s	remaining: 58.2ms
# 997:	learn: 0.3766014	total: 19.4s	remaining: 38.8ms
# 998:	learn: 0.3765244	total: 19.4s	remaining: 19.4ms
# 999:	learn: 0.3764046	total: 19.4s	remaining: 0us
# {'LinearRegression': {'fit_time': array([0.14953303, 0.07193899, 0.05760002, 0.05400515, 0.05890703]),
#   'score_time': array([0.00774693, 0.00129485, 0.0017302 , 0.00156784, 0.00129318]),
#   'estimator': [LinearRegression(),
#    LinearRegression(),
#    LinearRegression(),
#    LinearRegression(),
#    LinearRegression()],
#   'test_score': array([0.05954167, 0.0610645 , 0.06681388, 0.06713877, 0.03307559])},
#  'LGBMRegressor': {'fit_time': array([1.51356411, 0.72931314, 0.79235482, 0.87956095, 0.77128386]),
#   'score_time': array([0.01518106, 0.02098298, 0.01409626, 0.02378798, 0.01248813]),
#   'estimator': [LGBMRegressor(),
#    LGBMRegressor(),
#    LGBMRegressor(),
#    LGBMRegressor(),
#    LGBMRegressor()],
#   'test_score': array([0.0815282 , 0.07432976, 0.10912707, 0.09496173, 0.0884023 ])},
#  'XGBRegressor': {'fit_time': array([11.263273  , 12.05481601, 12.52139115, 12.31602383, 12.7584362 ]),
#   'score_time': array([0.0170188 , 0.01834702, 0.01343894, 0.0134871 , 0.01376104]),
#   'estimator': [XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#                 colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#                 early_stopping_rounds=None, enable_categorical=False,
#                 eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#                 importance_type=None, interaction_constraints='',
#                 learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#                 max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#                 missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#                 num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#                 reg_lambda=1, ...),
#    XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#                 colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#                 early_stopping_rounds=None, enable_categorical=False,
#                 eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#                 importance_type=None, interaction_constraints='',
#                 learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#                 max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#                 missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#                 num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#                 reg_lambda=1, ...),
#    XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#                 colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#                 early_stopping_rounds=None, enable_categorical=False,
#                 eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#                 importance_type=None, interaction_constraints='',
#                 learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#                 max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#                 missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#                 num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#                 reg_lambda=1, ...),
#    XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#                 colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#                 early_stopping_rounds=None, enable_categorical=False,
#                 eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#                 importance_type=None, interaction_constraints='',
#                 learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#                 max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#                 missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#                 num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#                 reg_lambda=1, ...),
#    XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#                 colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#                 early_stopping_rounds=None, enable_categorical=False,
#                 eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#                 importance_type=None, interaction_constraints='',
#                 learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#                 max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#                 missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#                 num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#                 reg_lambda=1, ...)],
#   'test_score': array([0.03570507, 0.02176002, 0.04835858, 0.04670403, 0.04651431])},
#  'CatBoostRegressor': {'fit_time': array([16.12923384, 16.08655572, 17.13425207, 19.28371882, 20.81397319]),
#   'score_time': array([0.09847713, 0.09805417, 0.1294148 , 0.09689808, 0.09019375]),
#   'estimator': [<catboost.core.CatBoostRegressor at 0x12e3075e0>,
#    <catboost.core.CatBoostRegressor at 0x12444c880>,
#    <catboost.core.CatBoostRegressor at 0x12444c8b0>,
#    <catboost.core.CatBoostRegressor at 0x12444e0b0>,
#    <catboost.core.CatBoostRegressor at 0x12444e320>],
#   'test_score': array([0.10169137, 0.0978134 , 0.11522388, 0.09917805, 0.10927523])},
#  'SGDRegressor': {'fit_time': array([0.08808684, 0.05454326, 0.15674114, 0.03821397, 0.04309821]),
#   'score_time': array([0.01149917, 0.00324488, 0.00109196, 0.00119996, 0.00203872]),
#   'estimator': [SGDRegressor(),
#    SGDRegressor(),
#    SGDRegressor(),
#    SGDRegressor(),
#    SGDRegressor()],
#   'test_score': array([ 4.43247199e-02, -6.41333031e+01, -7.46626481e+01, -1.43762697e+05,
#           6.24864299e-02])},
#  'KernelRidge': {'fit_time': array([91.35866499, 79.00427413, 74.93468213, 64.85984278, 77.30626082]),
#   'score_time': array([0.97477722, 0.69935703, 0.63531804, 0.50434208, 0.65348625]),
#   'estimator': [KernelRidge(),
#    KernelRidge(),
#    KernelRidge(),
#    KernelRidge(),
#    KernelRidge()],
#   'test_score': array([-5.91574514, -5.37129387, -5.55754688, -5.56414072, -6.87574334])},
#  'ElasticNet': {'fit_time': array([0.41300082, 0.01861405, 0.02199125, 0.01643109, 0.02117109]),
#   'score_time': array([0.01276112, 0.00129676, 0.00098085, 0.00129509, 0.00145197]),
#   'estimator': [ElasticNet(),
#    ElasticNet(),
#    ElasticNet(),
#    ElasticNet(),
#    ElasticNet()],
#   'test_score': array([-1.12059751e-05, -2.25615145e-04, -3.53546163e-05, -4.23462085e-05,
#          -1.23284635e-07])},
#  'BayesianRidge': {'fit_time': array([0.22273088, 0.10548782, 0.11377406, 0.10584211, 0.09742904]),
#   'score_time': array([0.00145102, 0.00125122, 0.00100398, 0.00146985, 0.00102496]),
#   'estimator': [BayesianRidge(),
#    BayesianRidge(),
#    BayesianRidge(),
#    BayesianRidge(),
#    BayesianRidge()],
#   'test_score': array([0.06166993, 0.06243793, 0.06612361, 0.06945878, 0.07140529])},
#  'GradientBoostingRegressor': {'fit_time': array([30.74278688, 30.86503291, 30.4690938 , 29.79087591, 30.59708381]),
#   'score_time': array([0.02940202, 0.01107621, 0.0078373 , 0.00713897, 0.00847697]),
#   'estimator': [GradientBoostingRegressor(),
#    GradientBoostingRegressor(),
#    GradientBoostingRegressor(),
#    GradientBoostingRegressor(),
#    GradientBoostingRegressor()],
#   'test_score': array([0.07663759, 0.06972186, 0.08207218, 0.08181177, 0.07739411])},
#  'SVR': {'fit_time': array([23.67543077, 23.67327881, 23.59180188, 23.25853825, 23.42177296]),
#   'score_time': array([16.5072782 , 16.27458906, 16.42112303, 16.01796103, 19.80193901]),
#   'estimator': [SVR(), SVR(), SVR(), SVR(), SVR()],
#   'test_score': array([0.00190955, 0.00493867, 0.0268723 , 0.01062934, 0.0128761 ])}}

# %%
best_models = performance_dict["ElasticNet"]["estimator"]

best_preds = [model.predict(X_test) for model in best_models]

len(best_preds[0])

# mae = [mean_absolute_error(y_test, pred) for pred in best_preds]
# mae

# ENresiduals = [pred - y_test for pred in best_preds]

# new = [0 if ENresiduals[i] < 0 else ENresiduals[i] for i in range(len(ENresiduals))]
# Out:
# 7276

# %%
df_lst = [pd.DataFrame(value) for key, value in performance_dict.items()]

for df in df_lst:
    df = df.sort_values(by = ['test_score'])

scores = {}
for name in names:
    scores[name] = performance_dict[name]["test_score"]

df_scores = pd.DataFrame(scores)
sorted = df_scores.mean().abs().sort_values()

fig, ax = plt.subplots()
ax = df_scores.mean().abs().sort_values().plot.barh(**{"logx": True})
fig.suptitle("5-Fold CV MAE on Log Scale ")

plt.show()
# sns.barplot( )

# scores = {performance_dict[name] for name in names}
plt.subplots_adjust(
top=0.89,
bottom=0.09,
left=0.32,
right=0.96,
hspace=0.185,
wspace=0.2)
# scores

# %%
clf = SGDRegressor()
clf2 = KNeighborsRegressor()

knns = cross_validate(**{"estimator": clf2, "X": X_train, "y": y_train, "cv": 5, "return_estimator": True})

# scores = cross_val_predict(clf, X_scaled, y, cv = 5)
# scores
# residuals = scores - y
# residuals

# sns.pointplot(x = y, y = residuals)

# %%
pred_knn = [model.predict(X_test) for model in knns["estimator"]]


mae = [mean_absolute_error(y_test, pred) for pred in pred_knn]
mae
# Out:
# [0.3856797691039033,
#  0.38531088510170425,
#  0.38661737218251785,
#  0.3848007146783947,
#  0.385153106102254]

# %%
knns
# Out:
# {'fit_time': array([0.01050401, 0.0071559 , 0.00668073, 0.00648499, 0.00835204]),
#  'score_time': array([2.57653499, 1.82548714, 2.07405305, 2.01010728, 1.94949031]),
#  'estimator': [KNeighborsRegressor(),
#   KNeighborsRegressor(),
#   KNeighborsRegressor(),
#   KNeighborsRegressor(),
#   KNeighborsRegressor()],
#  'test_score': array([-0.03891767, -0.01724103, -0.01372886, -0.01705853, -0.0237274 ])}
